# %% [markdown]
# **langchain is a model agnostic framework->if you later want to change the llm model you have to change a single line of code**

# %% [markdown]
# **In chains output of one thing become input of other**

# %% [markdown]
# **Minimal code is required such a complex tasks**

# %% [markdown]
# ## Components Of Langchain ##

# %% [markdown]
# **1)Models-> Component use for interacting with LLMs.
# We do no need to change complete code for every llm just two lines by using langchain models interface**
