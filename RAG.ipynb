# %% [markdown]
# ## LLMs were having these problems 1)No Private data.2)No recent data(knowledge cut off).3).hallucination.Which are solved by RAG ##

# %% [markdown]
# **LLM->Joint transformer based Neural Network.**

# %% [markdown]
# **The knowledge are data is stored  in the form of parameters in the model,which is also called parametric knowledge.**

# %% [markdown]
# **RAG came into picture because LLm has these limitations No access to private data,no recent info(knowledge cut off) and do Hallucination**

# %% [markdown]
# **Fine-Tuning->The training of a pre trained moel on domain specific data is fine tuning.e.g.Supervised,continued fine tuning.**

# %% [markdown]
# **Issues in fine tuning-> Computationaly expensive retraing model again and again,highly technical people require and if the data is updated then you have to again retrained the model.**

# %% [markdown]
# **In Context Learning->you show the LLM prompts and its sentiment and then it ecide the sentiment of new input.These prompts are called few shorts prompts.**

# %% [markdown]
# **Indexing->Creating external Knowledge base(ingestion,splitting,embeddings and storing to vectore store) is indexing.**

# %% [markdown]
# **Retrieval->To get most relevant pieces of information,from a built index on basis of user query.retriever->Convert user query to embeddings using same model we have used for text embeddings,do semantic search,rank documents and bring those documents.**
