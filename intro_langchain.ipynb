# %% [markdown]
# **Langchain->Framework Use to build LLM base applications.**

# %% [markdown]
# **Langchain Benefits are-> can wor with major LLMS,Can integrate tools wasily and is open source.**

# %% [markdown]
# **Langchain use for LLM-BAsed apps development**
