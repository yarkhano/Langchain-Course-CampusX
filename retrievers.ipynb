# %% [markdown]
# ## Retrievers ##

# %% [markdown]
# **Retrievers are categorized into the one which work on basis of data source and second the search methodolgy.**

# %%
#wikipedia retriver use to collect the things on basis of keywords .
from langchain_community.retrievers import WikipediaRetriever

retriever = WikipediaRetriever(top_k_results=2,language='en')

docs = retriever("Pakistan relation with india")
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_4056\631459972.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.retrievers import WikipediaRetriever
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\PycharmProjects\Langchain-Course-CampusX\.venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:39, in WikipediaAPIWrapper.validate_environment(cls, values)
#      38 try:
# ---> 39     import wikipedia
#      41     lang = values.get("lang", "en")
#
# ModuleNotFoundError: No module named 'wikipedia'
#
# During handling of the above exception, another exception occurred:
#
# ...
