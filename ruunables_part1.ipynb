# %% [markdown]
# ## Langchain created chains for different components but it later created some problems. It increased the maitanance issue and the big problem was that the chains were not able to connect seamlessly as they were not standardized. so the runnables solve this problem. ##

# %% [markdown]
# **Runnables->take some input process it and return output and all runnables have some common inerfaces like invokde etc.**
