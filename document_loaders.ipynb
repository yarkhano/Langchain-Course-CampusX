# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("p1.txt")
docs = loader.load()

# %%
print(docs[0])
# Out:
# page_content='Hi this is a dummy file.' metadata={'source': 'p1.txt'}

# %% [markdown]
# ## PDF Loader ##

# %% [markdown]
# **pypdf->is usful when we have simple pdfs not too much complex or have images or tables in it**

# %% [markdown]
# ## for high level pdfs we use other loaders where we have tables,images etc. ##

# %% [markdown]
# ## ##

# %% [markdown]
# ## lazy_load-> Use to load documents according to need.it load using streaming and wipe out existing and show new. ##

# %%
loader = TextLoader("p1.txt")
docs = loader.lazy_load()

# %% [markdown]
# ## Webaseloader use for static web pages,while for dynamic selenium is used. ##
